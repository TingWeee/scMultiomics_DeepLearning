# %%
from src.preprocessing_modules import *
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import hsv_to_rgb
import umap

# %%
tf.random.set_seed(3)

# %% [markdown]
# # First Data: GSE100866
#
# ## Gene Only

# %%
data_directory = 'Sample Datasets/GSE100866'
meta_data, pro, rna, cite_seq_data, labels_encoder, labels, data_with_targets = compile_data(data_directory, cell_type_col)
train_data, test_data, train_labels, test_labels = generate_training(data_with_targets, pro, gene_only = True)
history, autoencoder, encoder = gene_only_encoder(train_data, test_data, 64, 'GSE100866', 'gene_only')
# Perform the TSNE on the bottleneck layer of the encoded data and the non encoded data
N_predict = 2000
# Make the encoder do its job. We can now store this as an output to a var
training_predicted = encoder.predict(test_data[:N_predict])
# Perform TSNE on 2 components so we can visualise it.
train_encoded = TSNE(n_components = 2, init = 'pca', learning_rate = 'auto',random_state = 0).fit_transform(training_predicted)
train_unencoded = TSNE(n_components = 2, init = 'pca', learning_rate = 'auto',random_state = 0).fit_transform(test_data[:N_predict])
# Out:
# Reading Data in Sample Datasets/GSE100866/
#
# Metadata found!
# Protein Data Found!
# RNA-seq data found!
#
# Reading in the data!
# Loaded metadata
# Loaded protein data
# Loaded rna data
# Epoch 1/15
# 384/384 [==============================] - 7s 15ms/step - loss: 0.7651 - val_loss: 0.6972
# Epoch 2/15
# 384/384 [==============================] - 4s 11ms/step - loss: 0.6905 - val_loss: 0.6776
# Epoch 3/15
# 384/384 [==============================] - 4s 11ms/step - loss: 0.6831 - val_loss: 0.6739
# Epoch 4/15
# 384/384 [==============================] - 4s 11ms/step - loss: 0.6782 - val_loss: 0.6705
# Epoch 5/15
# 384/384 [==============================] - 4s 11ms/step - loss: 0.6739 - val_loss: 0.6677
# Epoch 6/15
# 384/384 [==============================] - 4s 10ms/step - loss: 0.6699 - val_loss: 0.6656
# Epoch 7/15
# 384/384 [==============================] - 4s 12ms/step - loss: 0.6663 - val_loss: 0.6634
# Epoch 8/15
# 384/384 [==============================] - 5s 12ms/step - loss: 0.6635 - val_loss: 0.6622
# Epoch 9/15
# 384/384 [==============================] - 5s 12ms/step - loss: 0.6607 - val_loss: 0.6622
# Epoch 10/15
# 384/384 [==============================] - 5s 12ms/step - loss: 0.6582 - val_loss: 0.6598
# Epoch 11/15
# 384/384 [==============================] - 5s 12ms/step - loss: 0.6554 - val_loss: 0.6592
# Epoch 12/15
# 384/384 [==============================] - 4s 11ms/step - loss: 0.6533 - val_loss: 0.6582
# Epoch 13/15
# 384/384 [==============================] - 5s 12ms/step - loss: 0.6510 - val_loss: 0.6578
# Epoch 14/15
# 384/384 [==============================] - 5s 12ms/step - loss: 0.6492 - val_loss: 0.6572
# Epoch 15/15
# 384/384 [==============================] - 5s 12ms/step - loss: 0.6476 - val_loss: 0.6565
# INFO:tensorflow:Assets written to: saved_models/GSE100866/gene_only_NHL2_DIV4_EPOCHS15_EncodingDim64_auto\assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: saved_models/GSE100866/gene_only_NHL2_DIV4_EPOCHS15_EncodingDim64_encoder\assets
# C:\Users\Darren\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
# C:\Users\Darren\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(

# %%
reducer = umap.UMAP()
train_encoded_umap = reducer.fit_transform(training_predicted)
train_unencoded_umap = reducer.fit_transform(test_data[:N_predict])

# %%
color = generate_color(labels_encoder, labels)
color_map = generate_colormap(color, labels_encoder, labels)
left, right = comparison_cluster(train_encoded, train_unencoded,test_labels, N_predict = 2000)
vis_data2d(train_encoded, train_unencoded, test_labels, labels_encoder, color_map, 2000,
           left_label = f'Encoded TSNE Gene Only-Score: {left}', right_label = f'Control TSNE-Score: {right}', spacer = 'GSE100866/geneOnly_TSNE')

color = generate_color(labels_encoder, labels)
color_map = generate_colormap(color, labels_encoder, labels)
left, right = comparison_cluster(train_encoded_umap, train_unencoded_umap,test_labels, N_predict = 2000)
vis_data2d(train_encoded_umap, train_unencoded_umap, test_labels, labels_encoder, color_map, 2000,
           left_label = f'Encoded UMAP Gene Only-Score: {left}', right_label = f'Control UMAP-Score: {right}', spacer = 'GSE100866/geneOnly_UMAP')
# Out:
# C:\Users\Darren\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Clustering Score of "first-arg data": 0.677
# Clustering Score of "second-arg data": 0.537
# C:\Users\Darren\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Clustering Score of "first-arg data": 0.7595
# Clustering Score of "second-arg data": 0.331

# %% [markdown]
# ## Gene and Protein

# %%
train_data, test_data, train_labels, test_labels = generate_training(data_with_targets, pro, gene_only = False)
gene_train_data,pro_train_data,gene_test_data,pro_test_data = split_training_with_labels(train_data, test_data, pro)

# %%
history, autodecoder, merged = gene_protein_encoder(pro_train_data,gene_train_data,pro_test_data, gene_test_data, 64, 'GSE100866', 'gene_pro')
# Perform the TSNE on the bottleneck layer of the encoded data and the non encoded data
N_predict = 2000
# Make the encoder do its job. We can now store this as an output to a var
training_predicted = merged.predict([gene_test_data[:N_predict],pro_test_data[:N_predict]])
# Perform TSNE on 2 components so we can visualise it.
train_encoded_gp = TSNE(n_components = 2, init = 'pca', learning_rate = 'auto',random_state = 0).fit_transform(training_predicted)
# Out:
# Epoch 1/15
# 384/384 [==============================] - 9s 21ms/step - loss: 1.7591 - dense_12_loss: 0.7651 - dense_14_loss: 0.9939 - val_loss: 1.5933 - val_dense_12_loss: 0.7198 - val_dense_14_loss: 0.8735
# Epoch 2/15
# 384/384 [==============================] - 7s 17ms/step - loss: 1.4541 - dense_12_loss: 0.6877 - dense_14_loss: 0.7664 - val_loss: 1.3820 - val_dense_12_loss: 0.6776 - val_dense_14_loss: 0.7044
# Epoch 3/15
# 384/384 [==============================] - 7s 17ms/step - loss: 1
2[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 500)         2000        ['dense_6[0][0]']
#  rmalization)
#
#  input_3 (InputLayer)           [(None, 25)]         0           []
#
#  dense_7 (Dense)                (None, 125)          62625       ['batch_normalization_5[0][0]']
#
#  dense_8 (Dense)                (None, 6)            156         ['input_3[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 125)         500         ['dense_7[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 6)           24          ['dense_8[0][0]']
#  rmalization)
#
#  concatenate (Concatenate)      (None, 131)          0           ['batch_normalization_6[0][0]',
#                                                                   'batch_normalization_7[0][0]']
#
#  dense_9 (Dense)                (None, 64)           8448        ['concatenate[0][0]']
#
#  dense_10 (Dense)               (None, 125)          8125        ['dense_9[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 125)         500         ['dense_10[0][0]']
#  rmalization)
#
#  dense_11 (Dense)               (None, 500)          63000       ['batch_normalization_8[0][0]']
#
#  dense_13 (Dense)               (None, 6)            390         ['dense_9[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 500)         2000        ['dense_11[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 6)           24          ['dense_13[0][0]']
#  ormalization)
#
#  dense_12 (Dense)               (None, 2000)         1002000     ['batch_normalization_9[0][0]']
#
#  dense_14 (Dense)               (None, 25)           175         ['batch_normalization_10[0][0]']
#
# ==================================================================================================
# Total params: 2,150,467
# Trainable params: 2,147,943
# Non-trainable params: 2,524
# __________________________________________________________________________________________________

# %%
autodecoder.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 2000)]       0           []
#
#  dense_6 (Dense)                (None, 500)          1000500     ['input_2[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 500)         2000        ['dense_6[0][0]']
#  rmalization)
#
#  input_3 (InputLayer)           [(None, 25)]         0           []
#
#  dense_7 (Dense)                (None, 125)          62625       ['batch_normalization_5[0][0]']
#
#  dense_8 (Dense)                (None, 6)            156         ['input_3[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 125)         500         ['dense_7[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 6)           24          ['dense_8[0][0]']
#  rmalization)
#
#  concatenate (Concatenate)      (None, 131)          0           ['batch_normalization_6[0][0]',
#                                                                   'batch_normalization_7[0][0]']
#
#  dense_9 (Dense)                (None, 64)           8448        ['concatenate[0][0]']
#
#  dense_10 (Dense)               (None, 125)          8125        ['dense_9[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 125)         500         ['dense_10[0][0]']
#  rmalization)
#
#  dense_11 (Dense)               (None, 500)          63000       ['batch_normalization_8[0][0]']
#
#  dense_13 (Dense)               (None, 6)            390         ['dense_9[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 500)         2000        ['dense_11[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 6)           24          ['dense_13[0][0]']
#  ormalization)
#
#  dense_12 (Dense)               (None, 2000)         1002000     ['batch_normalization_9[0][0]']
#
#  dense_14 (Dense)               (None, 25)           175         ['batch_normalization_10[0][0]']
#
# ==================================================================================================
# Total params: 2,150,467
# Trainable params: 2,147,943
# Non-trainable params: 2,524
# __________________________________________________________________________________________________

# %%
reducer = umap.UMAP()
train_encoded_gp_UMAP = reducer.fit_transform(training_predicted)

# %%
color = generate_color(labels_encoder, labels)
color_map = generate_colormap(color, labels_encoder, labels)
left, right = comparison_cluster(train_encoded_gp, train_encoded,test_labels, N_predict = 2000)
vis_data2d(train_encoded_gp, train_encoded, test_labels, labels_encoder, color_map, 2000, 
           left_label=f'Gene Protein TSNE-Score:{left}', right_label=f'Gene only TSNE-Score:{right}', spacer = 'GSE100866/gene_pro_TSNE')

left, right = comparison_cluster(train_encoded_gp_UMAP, train_encoded_umap,test_labels, N_predict = 2000)
vis_data2d(train_encoded_gp_UMAP, train_encoded_umap, test_labels, labels_encoder, color_map, 2000, 
           left_label=f'Gene Protein UMAP-Score: {left}', right_label=f'Gene only UMAP-Score: {right}', spacer = 'GSE100866/gene_pro_UMAP')
# Out:
# C:\Users\Darren\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Darren\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Clustering Score of "first-arg data": 0.927
# Clustering Score of "second-arg data": 0.677
# C:\Users\Darren\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Darren\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Clustering Score of "first-arg data": 0.8945
# Clustering Score of "second-arg data": 0.7595

# %% [markdown]
# ### Usage of Custom Encoders and Custome Decoders for N-Omics data, in this case 2.

# %%
encoding_g, n_feat_dim_g, node_layers_g, inputs_g = custom_encoder(gene_train_data.shape)
encoding_p, n_feat_dim_p, node_layers_p, inputs_p = custom_encoder(pro_train_data.shape, n_hidden_layer=1)

merged = custom_concat([encoding_g, encoding_p], 64)

decoder_g = custom_decoder(merged, n_feat_dim_g, node_layers_g)
decoder_p = custom_decoder(merged, n_feat_dim_p, node_layers_p)

history, autodecoder, merged_m = save_load_build_custom_autoencoders([inputs_g,inputs_p], [decoder_g,decoder_p], merged,
                                                                    [gene_train_data,pro_train_data], saved_model_dir_name = 'GSE100866')
N_predict = 2000
# Make the encoder do its job. We can now store this as an output to a var
training_predicted_2 = merged_m.predict([gene_test_data[:N_predict],pro_test_data[:N_predict]])
# Perform TSNE on 2 components so we can visualise it.
train_encoded_gp_2 = TSNE(n_components = 2, init = 'pca', learning_rate = 'auto',random_state = 0).fit_transform(training_predicted)
# Out:
# node_layers are not in the right order, reversing it...
# Epoch 1/15
# 384/384 [==============================] - 11s 24ms/step - loss: 1.7527 - dense_21_loss: 0.7606 - dense_23_loss: 0.9921
# Epoch 2/15
# 384/384 [==============================] - 255s 665ms/step - loss: 1.4643 - dense_21_loss: 0.6876 - dense_23_loss: 0.7767
# Epoch 3/15
# 384/384 [==============================] - 10s 27ms/step - loss: 1.3655 - dense_21_loss: 0.6830 - dense_23_loss: 0.6825
# Epoch 4/15
# 384/384 [==============================] - 8s 20ms/step - loss: 1.3230 - dense_21_loss: 0.6794 - dense_23_loss: 0.6436
# Epoch 5/15
# 384/384 [==============================] - 8s 20ms/step - loss: 1.3038 - dense_21_loss: 0.6762 - dense_23_loss: 0.6276
# Epoch 6/15
# 384/384 [==============================] - 8s 20ms/step - loss: 1.2905 - dense_21_loss: 0.6731 - dense_23_loss: 0.6173
# Epoch 7/15
# 384/384 [==============================] - 7s 18ms/step - loss: 1.2806 - dense_21_loss: 0.6704 - dense_23_loss: 0.6103
# Epoch 8/15
# 384/384 [==============================] - 8s 20ms/step - loss: 1.2736 - dense_21_loss: 0.6682 - dense_23_loss: 0.6054
# Epoch 9/15
# 384/384 [==============================] - 8s 22ms/step - loss: 1.2677 - dense_21_loss: 0.6662 - dense_23_loss: 0.6015
# Epoch 10/15
# 384/384 [==============================] - 8s 20ms/step - loss: 1.2616 - dense_21_loss: 0.6639 - dense_23_loss: 0.5977
# Epoch 11/15
# 384/384 [==============================] - 8s 20ms/step - loss: 1.2570 - dense_21_loss: 0.6621 - dense_23_loss: 0.5948
# Epoch 12/15
# 384/384 [==============================] - 6s 17ms/step - loss: 1.2529 - dense_21_loss: 0.6603 - dense_23_loss: 0.5927
# Epoch 13/15
# 384/384 [==============================] - 6s 17ms/step - loss: 1.2485 - dense_21_loss: 0.6587 - dense_23_loss: 0.5899
# Epoch 14/15
# 384/384 [==============================] - 8s 20ms/step - loss: 1.2446 - dense_21_loss: 0.6572 - dense_23_loss: 0.5874
# Epoch 15/15
# 384/384 [==============================] - 8s 21ms/step - loss: 1.2427 - dense_21_loss: 0.6559 - dense_23_loss: 0.5868
# INFO:tensorflow:Assets written to: saved_models/GSE100866/custom_N-2-EPOCHS15_auto\assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: saved_models/GSE100866/custom_N-2-EPOCHS15_merged\assets
# C:\Users\Darren\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(

# %%
autodecoder.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 2000)]       0           []
#
#  dense_15 (Dense)               (None, 500)          1000500     ['input_4[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 500)         2000        ['dense_15[0][0]']
#  ormalization)
#
#  input_5 (InputLayer)           [(None, 25)]         0           []
#
#  dense_16 (Dense)               (None, 125)          62625       ['batch_normalization_11[0][0]']
#
#  dense_17 (Dense)               (None, 6)            156         ['input_5[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 125)         500         ['dense_16[0][0]']
#  ormalization)
#
#  batch_normalization_13 (BatchN  (None, 6)           24          ['dense_17[0][0]']
#  ormalization)
#
#  concatenate_1 (Concatenate)    (None, 131)          0           ['batch_normalization_12[0][0]',
#                                                                   'batch_normalization_13[0][0]']
#
#  dense_18 (Dense)               (None, 64)           8448        ['concatenate_1[0][0]']
#
#  dense_19 (Dense)               (None, 125)          8125        ['dense_18[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 125)         500         ['dense_19[0][0]']
#  ormalization)
#
#  dense_20 (Dense)               (None, 500)          63000       ['batch_normalization_14[0][0]']
#
#  dense_22 (Dense)               (None, 6)            390         ['dense_18[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 500)         2000        ['dense_20[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 6)           24          ['dense_22[0][0]']
#  ormalization)
#
#  dense_21 (Dense)               (None, 2000)         1002000     ['batch_normalization_15[0][0]']
#
#  dense_23 (Dense)               (None, 25)           175         ['batch_normalization_16[0][0]']
#
# ==================================================================================================
# Total params: 2,150,467
# Trainable params: 2,147,943
# Non-trainable params: 2,524
# __________________________________________________________________________________________________

# %%
reducer = umap.UMAP()
train_encoded_gp_UMAP = reducer.fit_transform(training_predicted)
train_encoded_gp_2_UMAP = reducer.fit_transform(training_predicted_2)

# %%
color = generate_color(labels_encoder, labels)
color_map = generate_colormap(color, labels_encoder, labels)

left, right = comparison_cluster(train_encoded_gp_2, train_encoded_gp,test_labels, N_predict = 2000)
vis_data2d(train_encoded_gp_2, train_encoded_gp, test_labels, labels_encoder, color_map, 2000, 
           left_label=f'Gene Protein Custom TSNE-Score:{left}', right_label=f'Gene Protein TSNE-Score:{right}', spacer = 'GSE100866/gene_pro_custom_TSNE')
left, right = comparison_cluster(train_encoded_gp_2_UMAP, train_encoded_gp_UMAP,test_labels, N_predict = 2000)
vis_data2d(train_encoded_gp_2_UMAP, train_encoded_gp_UMAP, test_labels, labels_encoder, color_map, 2000, 
           left_label=f'Gene Protein Custom UMAP-Score:{left}', right_label=f'Gene Protein UMAP-Score:{right}', spacer = 'GSE100866/gene_pro_custom_UMAP')
# Out:
# C:\Users\Darren\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Darren\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Clustering Score of "first-arg data": 0.927
# Clustering Score of "second-arg data": 0.927
# C:\Users\Darren\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Darren\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Clustering Score of "first-arg data": 0.9155
# Clustering Score of "second-arg data": 0.8965

# %%
from sklearn.decomposition import PCA
train_encoded_gp_PCA = PCA(n_components = 2).fit_transform(training_predicted)
train_encoded_gp_2_PCA = PCA(n_components = 2).fit_transform(training_predicted_2)
vis_data2d(train_encoded_gp_2_PCA, train_encoded_gp_PCA, test_labels, labels_encoder, color_map, 2000, 
           left_label=f'Gene Protein Custom PCA-Score:{left}', right_label=f'Gene Protein PCA-Score:{right}', spacer = 'GSE100866/gene_pro_custom_PCA')

# %% [markdown]
# # Second Data: GSE128639

# %%
data_directory = 'Sample Datasets/GSE128639'
meta_data, pro, rna, cite_seq_data, labels_encoder, labels, data_with_targets = compile_data(data_directory, cell_type_col)
train_data, test_data, train_labels, test_labels = generate_training(data_with_targets, pro, gene_only = False)
gene_train_data,pro_train_data,gene_test_data,pro_test_data = split_training_with_labels(train_data, test_data, pro)
history, autodecoder, merged = gene_protein_encoder(pro_train_data,gene_train_data,pro_test_data, gene_test_data, 64, 'GSE128639', 'gene_pro')
# Perform the TSNE on the bottleneck layer of the encoded data and the non encoded data
N_predict = 2000
# Make the encoder do its job. We can now store this as an output to a var
training_predicted = merged.predict([gene_test_data[:N_predict],pro_test_data[:N_predict]])
# Perform TSNE on 2 coponents so we can visualise it.
train_encoded = TSNE(n_components = 2, init = 'pca', learning_rate = 'auto',random_state = 0).fit_transform(training_predicted)
train_unencoded = TSNE(n_components = 2, init = 'pca', learning_rate = 'auto',random_state = 0).fit_transform(test_data[:N_predict])
color = generate_color(labels_encoder, labels)
color_map = generate_colormap(color, labels_encoder, labels)
left, right = comparison_cluster(train_encoded, train_unencoded,test_labels, N_predict = 2000)
vis_data2d(train_encoded, train_unencoded, test_labels, labels_encoder, color_map, 2000, 
           left_label=f'Gene Protein TSNE-Score:{left}', right_label=f'Control TSNE-Score:{right}', spacer = 'GSE128639/gene_pro_TSNE')
# Out:
# Reading Data in Sample Datasets/GSE128639/
#
# Metadata found!
# Protein Data Found!
# RNA-seq data found!
#
# Reading in the data!
# Loaded metadata
# Loaded protein data
# Loaded rna data
# MODEL ALREADY EXISTS, TO RETRAIN, SET PARAM "override = True"
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# C:\Users\Darren\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
# C:\Users\Darren\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
# C:\Users\Darren\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Clustering Score of "first-arg data": 0.9175
# Clustering Score of "second-arg data": 0.6675

# %%
reducer = umap.UMAP()
train_encoded_umap = reducer.fit_transform(training_predicted)
train_unencoded_umap = reducer.fit_transform(test_data[:N_predict])
left, right = comparison_cluster(train_encoded_umap, train_unencoded_umap,test_labels, N_predict = 2000)
vis_data2d(train_encoded_umap, train_unencoded_umap, test_labels, labels_encoder, color_map, 2000, 
           left_label=f'Gene Protein UMAP-Score:{left}', right_label=f'Control UMAP-Score:{right}', spacer = 'GSE128639/gene_pro_UMAP')
# Out:
# C:\Users\Darren\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Darren\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Clustering Score of "first-arg data": 0.9055
# Clustering Score of "second-arg data": 0.428
