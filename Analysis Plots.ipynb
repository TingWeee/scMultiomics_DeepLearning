# %%
from src.preprocessing_modules import *
from src.dno_modules2 import *
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import hsv_to_rgb
import umap
import pymde
import torch
import seaborn as sns
sns.set_theme(style='white')
import plotly.express as px
import dill
from sklearn.decomposition import PCA
import colorcet as cc

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## GSE128639

# %%
plotReloadedObj("saved_datasetObjs/GSE128639.pickle","celltype.l2",saveplot = "figures/GSE128639.png")
# Out:
# gene_protein 0.89273604590506
# gene_only 0.7382303077725613
# cite_pca 0.6828051643192489
# control 0.2677034428794992

# %% [markdown]
# ## GSE164378

# %%
plotReloadedObj("saved_datasetObjs/GSE164378.pickle","celltype.l2",saveplot = "figures/GSE164378_l2.png")
# Out:
# gene_protein 0.8268709001614177
# gene_only 0.81704845966274
# cite_pca 0.7214685578871449
# control 0.8135110073153141

# %%
# Note, the score here is still refering l2
plotReloadedObj("saved_datasetObjs/GSE164378.pickle","celltype.l1",saveplot = "figures/GSE164378_l1.png")
# Out:
# gene_protein 0.8268709001614177
# gene_only 0.81704845966274
# cite_pca 0.7214685578871449
# control 0.8135110073153141

# %% [markdown]
# ## GSE100866

# %%
plotReloadedObj("saved_datasetObjs/GSE100866.pickle","rna_annotations", colormap = px.colors.qualitative.Light24, saveplot = "figures/GSE100866.png")
# Out:
# gene_protein 0.7967067764407854
# gene_only 0.7963267891070298
# cite_pca 0.8444585180493983
# control 0.668777707409753

# %% [markdown]
# ## GSE153056

# %%
plotReloadedObj("saved_datasetObjs/GSE153056.pickle","Phase", colormap="bright", saveplot ="figures/GSE153056.png")
# Out:
# gene_protein 0.9262868445173429
# gene_only 0.942110087317285
# cite_pca 0.9514689565343238
# control 0.9168797337064016

# %% [markdown]
# ## GSE166489

# %% [markdown]
# ### severe

# %%
plotReloadedObj("saved_datasetObjs/GSM5073055.pickle",'predicted.celltype.l2', saveplot ="figures/GSM5073055.png")
# Out:
# gene_protein 0.8593066666666667
# gene_only 0.8736
# cite_pca 0.8801066666666667
# control 0.6353066666666667

# %%
plotReloadedObj("saved_datasetObjs/GSM5073056.pickle",'predicted.celltype.l2',saveplot ="figures/GSM5073056.png")
# Out:
# gene_protein 0.863458110516934
# gene_only 0.8449197860962567
# cite_pca 0.8477718360071301
# control 0.7467023172905526

# %% [markdown]
# ## Normal

# %%
plotReloadedObj("saved_datasetObjs/GSM5073070.pickle",'predicted.celltype.l2',saveplot ="figures/GSM5073070.png")
# Out:
# gene_protein 0.7523237361142598
# gene_only 0.7270460213103604
# cite_pca 0.78428927680798
# control 0.7298798458399456

# %%
plotReloadedObj("saved_datasetObjs/GSM5073071.pickle",'predicted.celltype.l2', colormap = cc.glasbey_light, saveplot ="figures/GSM5073071.png")
# Out:
# gene_protein 0.7517970835900596
# gene_only 0.7391661532142124
# cite_pca 0.7725405627438899
# control 0.6971657424522489

# %%
plotReloadedObj("saved_datasetObjs/GSM5073072.pickle",'predicted.celltype.l2', colormap = cc.glasbey_light, saveplot ="figures/GSM5073072.png")
# Out:
# gene_protein 0.7710405674249632
# gene_only 0.7553844823112188
# cite_pca 0.7546925006487328
# control 0.686618804601678

# %% [markdown]
# ## Kotliarov et al., 2020

# %%
plotReloadedObj("saved_datasetObjs/KotliarovLow.pickle",'celltype',colormap = cc.glasbey,legendAnchor = (1.15, 0.5),saveplot ="figures/kotliarovLow.png")
# Out:
# gene_protein 0.8850416632958499
# gene_only 0.7453280478925653
# cite_pca 0.8786505946120864
# control 0.7543483536930669

# %%
plotReloadedObj("saved_datasetObjs/KotliarovHigh.pickle",'celltype',legendAnchor = (1.15, 0.5),colormap = cc.glasbey, saveplot ="figures/kotliarovHigh.png")
# Out:
# gene_protein 0.9017521682643351
# gene_only 0.7693388110537589
# cite_pca 0.8727834544752273
# control 0.6761824502264827
